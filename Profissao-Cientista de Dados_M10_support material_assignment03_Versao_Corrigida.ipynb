# %% [markdown]
# # Módulo 10 tarefa 03
# Considere a mesma base de dados utilizada na tarefa 1 ```previsao_de_renda.csv```.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
base = pd.read_csv('previsao_de_renda.csv')
base.head()
# Out:
#    Unnamed: 0    data_ref  index sexo  posse_de_veiculo  posse_de_imovel  \
# 0           0  2015-01-01   8682    F             False             True
# 1           1  2015-01-01  12830    M              True             True
# 2           2  2015-01-01   2885    M              True             True
# 3           3  2015-01-01  16168    F              True            False
# 4           4  2015-01-01  12438    M             False            False
#
#    qtd_filhos   tipo_renda           educacao estado_civil tipo_residencia  \
# 0           1  Assalariado         Secundário       Casado            Casa
# 1           0   Empresário         Secundário       Casado            Casa
# 2           2  Assalariado  Superior completo       Casado            Casa
# 3           0   Empresário         Secundário       Casado            Casa
# 4           0  Assalariado         Secundário       Casado            Casa
#
#    idade  tempo_emprego  qt_pessoas_residencia    mau    renda
# ...

# %% [markdown]
# 1) Construa um gráfico de barras para avaliar a distribuição das variáveis qualitativas no tempo. Você acha que houve alguma alteração importante a ser investigada?

# %%
grf_sexo = sns.countplot(x='data_ref',  hue = 'sexo', data=base)

ticks = grf_sexo.set_xticks(list(range(base['data_ref'].nunique())))
labels = grf_sexo.set_xticklabels(base['data_ref'].unique(), rotation=65)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
grf_tipo_renda = sns.countplot(x='data_ref',  hue = 'tipo_renda', data=base)

ticks = grf_tipo_renda.set_xticks(list(range(base['data_ref'].nunique())))
labels = grf_tipo_renda.set_xticklabels(base['data_ref'].unique(), rotation=65)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
grf_educacao = sns.countplot(x='data_ref',  hue = 'educacao', data=base)

ticks = grf_educacao.set_xticks(list(range(base['data_ref'].nunique())))
labels = grf_educacao.set_xticklabels(base['data_ref'].unique(), rotation=65)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
grf_estado_civil = sns.countplot(x='data_ref',  hue = 'estado_civil', data=base)

ticks = grf_estado_civil.set_xticks(list(range(base['data_ref'].nunique())))
labels = grf_estado_civil.set_xticklabels(base['data_ref'].unique(), rotation=65)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
grf_tipo_residencia = sns.countplot(x='data_ref',  hue = 'tipo_residencia', data=base)

ticks = grf_tipo_residencia.set_xticks(list(range(base['data_ref'].nunique())))
labels = grf_tipo_residencia.set_xticklabels(base['data_ref'].unique(), rotation=65)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %% [markdown]
# 2) Para cada variável qualitativa, construa um gráfico mostrando as médias de cada nível da variável no tempo e avalie a estabilidade. Houve alguma alteração importante? Você acha que se pode utilizar essas variáveis em uma modelagem?

# %%
base['data_ref'] = pd.to_datetime(base['data_ref'], format='%Y-%m-%d')

# %%
ax = sns.pointplot(x="data_ref", y="posse_de_veiculo", hue = 'sexo',
                   data=base, dodge=True, ci = 95)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.30),ncol = 3)

tick_labs = base['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(base['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=90)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.50),ncol = 3)
# Out:
# C:\Users\Belit\AppData\Local\Temp\ipykernel_11280\383107451.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   ax = sns.pointplot(x="data_ref", y="posse_de_veiculo", hue = 'sexo',

# %%
ax = sns.pointplot(x="data_ref", y="posse_de_imovel", hue = 'sexo',
                   data=base, dodge=True, ci = 95)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.30),ncol = 3)

tick_labs = base['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(base['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=90)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.50),ncol = 3)
# Out:
# C:\Users\Belit\AppData\Local\Temp\ipykernel_11280\3568102649.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   ax = sns.pointplot(x="data_ref", y="posse_de_imovel", hue = 'sexo',

# %%
ax = sns.pointplot(x="data_ref", y="idade", hue = 'sexo',
                   data=base, dodge=True, ci = 95)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.30),ncol = 3)

tick_labs = base['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(base['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=90)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.50),ncol = 3)
# Out:
# C:\Users\Belit\AppData\Local\Temp\ipykernel_11280\1650823119.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   ax = sns.pointplot(x="data_ref", y="idade", hue = 'sexo',

# %%
ax = sns.pointplot(x="data_ref", y="tempo_emprego", hue = 'sexo',
                   data=base, dodge=True, ci = 95)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.30),ncol = 3)

tick_labs = base['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(base['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=90)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.50),ncol = 3)
# Out:
# C:\Users\Belit\AppData\Local\Temp\ipykernel_11280\536018136.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   ax = sns.pointplot(x="data_ref", y="tempo_emprego", hue = 'sexo',

# %%
ax = sns.pointplot(x="data_ref", y="qt_pessoas_residencia", hue = 'sexo',
                   data=base, dodge=True, ci = 95)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.30),ncol = 3)

tick_labs = base['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(base['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=90)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.50),ncol = 3)
# Out:
# C:\Users\Belit\AppData\Local\Temp\ipykernel_11280\3168631992.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   ax = sns.pointplot(x="data_ref", y="qt_pessoas_residencia", hue = 'sexo',

# %%
ax = sns.pointplot(x="data_ref", y="renda", hue = 'sexo',
                   data=base, dodge=True, ci = 95)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.30),ncol = 3)

tick_labs = base['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(base['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=90)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.50),ncol = 3)
# Out:
# C:\Users\Belit\AppData\Local\Temp\ipykernel_11280\2744410721.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   ax = sns.pointplot(x="data_ref", y="renda", hue = 'sexo',

# %% [markdown]
# ## Insights - Clientes da base de previsão de renda
#
#
#
# - A base é composta pela maioria de clientes do sexo feminino;
# - Maior parte dos cliente são assalariados;
# - Entre os meses de Setembro de 2015 até Março 2016 houve um aumento considerável de clientes com a graduação superior completa;
# - A grande maioria dos clientes são casados e vivem em casas;
# - Há maior porcentagem dos clientes dos sexo masculino que possuem carro;
# - E em contra partida, as clientes do sexo feminino são a maioria donas de imóveis, exceto picos dos meses de Setembro e Outubro de 2015 que o cenário se inverte.
# - A base ainda conta com as clientes do sexo feminino mais velhas e com maior tempo de emprego, e os clientes do sexo masculino possuem maior renda e são mais jovens.
